# %% [markdown]
# # Data Analysis Project Steps
# 1. Create a Problem Statement.
# 2. Identify the dta you want to analyze.
# 3. Explore and clean the data.
# 4. Analyze the data to get useful insights.
# 5. Present the data in terms of reports of dashboards suing visualization.

# %% [markdown]
# # 1. Introduction and Problem Statement
# Of course. Based on the Jupyter Notebook analysis and the additional context you've provided, I have compiled the complete data analysis report.
#
# Analysis of Hotel Booking Cancellations for City Hotel and Resort Hotel
# Report prepared for: Management of City Hotel and Resort Hotel
#
# Date: August 23, 2025
#
# Subject: An analysis of the factors influencing hotel booking cancellations and strategies to mitigate revenue loss.
#
# 1. Introduction and Problem Statement
# In recent years, City Hotel and Resort Hotel have seen high cancellation rates. Each hotel is now dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use. The biggest factor affecting the effectiveness of earning income is booking cancellations, which result in vacant rooms for the booked length of time.
#
# Consequently, lowering cancellation rates is the primary goal for both hotels. The objective is to increase their efficiency in generating revenue by understanding the patterns and drivers behind cancellations. This report will analyze hotel booking cancellations and other relevant factors to provide thorough business advice to address this problem.
# Of course. Based on the Jupyter Notebook analysis and the additional context you've provided, I have compiled the complete data analysis report.
#
# Analysis of Hotel Booking Cancellations for City Hotel and Resort Hotel
# Report prepared for: Management of City Hotel and Resort Hotel
#
# Date: August 23, 2025
#
# Subject: An analysis of the factors influencing hotel booking cancellations and strategies to mitigate revenue loss.
#
# 1. Introduction and Problem Statement
# - In recent years, City Hotel and Resort Hotel have seen high cancellation rates. Each hotel is now dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use. The biggest factor affecting the effectiveness of earning income is booking cancellations, which result in vacant rooms for the booked length of time.
# - Consequently, lowering cancellation rates is the primary goal for both hotels. The objective is to increase their efficiency in generating revenue by understanding the patterns and drivers behind cancellations. This report will analyze hotel booking cancellations and other relevant factors to provide thorough business advice to address this problem.
#
# 2. Research Questions
# - The analysis was guided by the following core questions:
# - What are the variables that affect hotel reservation cancellations?
# - How can we improve the process surrounding hotel reservation cancellations?
# - How can this analysis assist hotels in making better pricing and promotional decisions?
# Of course. Based on the Jupyter Notebook analysis and the additional context you've provided, I have compiled the complete data analysis report.
#
# Analysis of Hotel Booking Cancellations for City Hotel and Resort Hotel
# Report prepared for: Management of City Hotel and Resort Hotel
#
# Date: August 23, 2025
#
# Subject: An analysis of the factors influencing hotel booking cancellations and strategies to mitigate revenue loss.
#
# 1. Introduction and Problem Statement
# - In recent years, City Hotel and Resort Hotel have seen high cancellation rates. Each hotel is now dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use. The biggest factor affecting the effectiveness of earning income is booking cancellations, which result in vacant rooms for the booked length of time.
#
# - Consequently, lowering cancellation rates is the primary goal for both hotels. The objective is to increase their efficiency in generating revenue by understanding the patterns and drivers behind cancellations. This report will analyze hotel booking cancellations and other relevant factors to provide thorough business advice to address this problem.
#
# 2. Research Questions
#
# - The analysis was guided by the following core questions:
#
# - What are the variables that affect hotel reservation cancellations?
#
# - How can we improve the process surrounding hotel reservation cancellations?
#
# - How can this analysis assist hotels in making better pricing and promotional decisions?
#
# 3. Hypotheses
#
# - To direct the investigation, the following initial hypotheses were formulated:
#
# - More cancellations occur when room prices are higher.
#
# - When there is a longer waiting list, customers tend to cancel more frequently.
#
# - The majority of clients are using offline travel agents to make their reservations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./hotel_bookings 2.csv')
df.head(2)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type  adr  \
# 0    NaN     NaN                    0     Transient  0.0
# 1    NaN     NaN                    0     Transient  0.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Changing the format of data

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])
#
# File c:\Users\lucky\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066             result = arg.tz_localize("utc")
#    1067 elif isinstance(arg, ABCSeries):
# -> 1068     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1069     if not cache_array.empty:
#    1070         result = arg.map(cache_array)
#
# File c:\Users\lucky\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\tools\datetimes.py:249, in _maybe_cache(arg, format, cache, convert_listlike)
#     247 unique_dates = unique(arg)
# ...

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status reservation_status_date
# count        119390        119390             119390                  119390
# unique            3             4                  3                     926
# ...

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %% [markdown]
# Checking how many null value are in the data set

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# Removing col and rows

# %%
# df.drop(['country','agent'] , axis=1 , inplace=True)  #remove coll as the axis = 1 and made changes in df as the inplace is true.
# df.dropna(inplace=True)
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# company                           0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# Removing the outliear

# %%
df = df[df['adr'] < 500]

# %% [markdown]
# # Data Analysis And Visualizations

# %%
cancelled_per = df['is_canceled'].value_counts(normalize = True)  # values_counts give count of freq of a cat. present   normalize give percenatge 
print(cancelled_per)

plt.figure(figsize=(5,4))
plt.title('Resevation Status Count')
plt.bar(['Not Canceled' , 'Canceled'] , df['is_canceled'].value_counts() , edgecolor = 'k', width=0.7)
plt.show()
# Out:
# is_canceled
# 0    0.824776
# 1    0.175224
# Name: proportion, dtype: float64

# %% [markdown]
# <!-- percentage of is canceled -->

# %%
plt.figure(figsize=(8, 4))
ax1 = sns.countplot(
    x='hotel',
    hue='is_canceled',
    data=df,
    palette='Blues'
)

# Legend with proper labels
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(
    title="Cancellation Status",
    labels=["Not Canceled", "Canceled"],
    loc="upper right",
    bbox_to_anchor=(1.25, 1)
)

# Titles and labels
plt.title("Reservation Status in Different Hotels", fontsize=18, weight="bold")
plt.xlabel("Hotel", fontsize=14)
plt.ylabel("Number of Reservations", fontsize=14)

# Add count labels above bars
for p in ax1.patches:
    ax1.annotate(
        str(p.get_height()),
        (p.get_x() + p.get_width() / 2., p.get_height()),
        ha='center',
        va='bottom',
        fontsize=9,
        color='black',
        xytext=(0, 3),
        textcoords='offset points'
    )

plt.tight_layout()
plt.show()

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.869048
# 1    0.130952
# Name: proportion, dtype: float64

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.787476
# 1    0.212524
# Name: proportion, dtype: float64

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
resort_hotel['adr'].plot(figsize=(20,8), label="Resort Hotel", linewidth=2.5)
city_hotel['adr'].plot(label="City Hotel", linewidth=2.5)

plt.title("Average Daily Rate (ADR) in City vs Resort Hotels", fontsize=28, weight="bold")
plt.xlabel("Date", fontsize=18)
plt.ylabel("Average Daily Rate (ADR)", fontsize=18)
plt.legend(fontsize=20)
plt.grid(alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(16, 8))

ax1 = sns.countplot(
    x='month_name',       # use month_name for prettier labels
    hue='is_canceled',
    data=df,
    palette='bright',
    order=["January","February","March","April","May","June",
           "July","August","September","October","November","December"]  # keep months in order
)

# Title & labels
plt.title("Reservation Status by Month", fontsize=22, weight="bold")
plt.xlabel("Month", fontsize=16)
plt.ylabel("Number of Reservations", fontsize=16)

# Legend
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(
    title="Cancellation Status",
    labels=["Not Canceled", "Canceled"],
    fontsize=14,
    title_fontsize=14,
    loc="upper right"
)

# Rotate x labels for clarity
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title("Adr", fontsize=28, weight="bold")
plt.bar('month','adr',data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %%
cancelled_data = df[df['is_canceled'] == 1]
top_10_country = cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(8,8))
plt.title('Top 10  countries with reservation canceled')
plt.pie(top_10_country , autopct='%.2f' ,labels= top_10_country.index)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.473046
# Offline TA/TO    0.202856
# Groups           0.165935
# Direct           0.105587
# Corporate        0.044350
# Complementary    0.006223
# Aviation         0.001985
# Undefined        0.000017
# Name: proportion, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.468954
# Groups           0.273539
# Offline TA/TO    0.187930
# Direct           0.043732
# Corporate        0.022431
# Complementary    0.002193
# Aviation         0.001176
# Undefined        0.000045
# Name: proportion, dtype: float64

# %%
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date' , inplace=True)

not_cancelled_data = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date' , inplace=True)

plt.figure(figsize=(20,3))
plt.title('Avg Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'] , not_cancelled_df_adr['adr'],label = 'not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'] , label = 'cancelled')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\lucky\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:1811, in Axis.convert_units(self, x)
#    1810 try:
# -> 1811     ret = self._converter.convert(x, self.units, self)
#    1812 except Exception as e:
#
# File c:\Users\lucky\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\category.py:57, in StrCategoryConverter.convert(value, unit, axis)
#      56 # force an update so it also does type checking
# ---> 57 unit.update(values)
#      58 s = np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# File c:\Users\lucky\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\category.py:217, in UnitData.update(self, data)
#     215 for val in OrderedDict.fromkeys(data):
#     216     # OrderedDict just iterates over unique values in data.
# ...

# %% [markdown]
# # Recommendations
# Based on the analysis, the following actions are recommended to reduce cancellation rates and improve revenue generation:
#
# - Revise Pricing Strategies: Since cancellation rates rise as the price does, hotels should review their pricing. The City Hotel, in particular, should consider offering discounts or implementing more competitive pricing strategies to reduce the high ADR that correlates with cancellations.
#
# - Targeted Holiday Discounts: The cancellation ratio for the Resort Hotel appears to be higher during peak times like weekends and holidays. Offering reasonable discounts during these periods could incentivize customers to keep their reservations.
#
# - Launch January Marketing Campaigns: Given that January is the month with the highest number of cancellations, hotels should launch targeted marketing campaigns or promotions during this time to increase revenue and mitigate the impact of cancellations.
#
# - Enhance Service Quality for Key Markets: To reduce the high cancellation rate from Portugal, hotels should focus on increasing the quality of their services and overall guest experience for this market segment. This could involve tailored communication, special offers, or improved on-site services.
#
# # Conclusion
#
# This analysis confirms that hotel reservation cancellations are a significant issue driven by several key factors, including high pricing (ADR), seasonality (peaking in January), hotel type (higher in the City Hotel), and customer origin (predominantly Portugal). The data clearly supports the initial hypothesis that price is a major driver of cancellations. By implementing targeted recommendations such as dynamic pricing, seasonal promotions, and enhanced service for key demographics, both City Hotel and Resort Hotel can effectively reduce their cancellation rates, improve room utilization, and ultimately increase their annual revenue.
